# %%
# %pip install -q krauncher-jupyter

# %%
import os, getpass

os.environ["CAS_API_KEY"] = getpass.getpass("CAS_API_KEY: ")

# %%
# %load_ext krauncher_magic

# %%
numbers = [1, 2, 3, 4]
power = 2

# %%
# %%krauncher --in numbers,power --out result --estimate
# result = sum(n**power for n in numbers)

# %%
# %%krauncher --in numbers,power --out result
# result = sum(n**power for n in numbers)

# %%
print('result =', result)
